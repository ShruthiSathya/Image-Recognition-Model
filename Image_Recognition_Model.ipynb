# %% [markdown]
# Image Recognition Model --> This model is designated to

# %%
#Need to install tensor flow 2.0.0
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.9.2
# Uninstalling tensorflow-2.9.2:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.8/dist-packages/tensorflow-2.9.2.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.9.2

# %%
# !pip install tensorflow==2.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 516.3 MB 3.4 kB/s
# ...
#      |████████████████████████████████| 3.0 MB 65.0 MB/s
# ...
#      |████████████████████████████████| 26.0 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 454 kB 60.5 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 56.2 MB/s
# ...
#      |████████████████████████████████| 152 kB 62.3 MB/s
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.2.0
#     Uninstalling cachetools-5.2.0:
#       Successfully uninstalled cachetools-5.2.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.15.0
#     Uninstalling google-auth-2.15.0:
#       Successfully uninstalled google-auth-2.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
# ...

# %%
# !pip install q keras==2.3.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 377 kB 8.0 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.7 MB/s
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
# ...

# %%
import tensorflow as tf
print(tf. __version__)
# Out:
# 2.2.0

# %%
#Data Preparation
from __future__ import absolute_import, division, print_function, unicode_literals
# !pip install keras
# !pip install numpy
import pandas as pd
import tensorflow as tf
import shutil
import os

import cv2
import os

from PIL import Image
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Activation, Dense
from tensorflow.keras.models import Model

import pandas as pd
import cv2
import json
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.layers import Dense, Dropout, Flatten, GlobalAveragePooling2D,AveragePooling2D,Conv2D
from keras.models import Sequential
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.utils.vis_utils import plot_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau,EarlyStopping,ModelCheckpoint,LearningRateScheduler
from keras import backend as K
from tensorflow.keras.utils import to_categorical
import os
import shutil
import numpy as np

import sklearn.metrics as sk

from time import time
from datetime import datetime

from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input
# # prepare the image for the VGG model
# image = preprocess_input(image)
# Out:
# Using TensorFlow backend.

# %%
train_small_dataset = pd.read_csv("/content/drive/MyDrive/train_small.csv")

index_list = []
for index, row in train_small_dataset.iterrows():
  index_list.append(row[0]%10)
train_small_dataset['Remainder'] = index_list

train_small_dataset

destination_list=[]
for index, row in train_small_dataset.iterrows():
  if row[3]<=6:
    destination_list.append("train")
  elif row[3]==7:
    destination_list.append("validate")
  else:
    destination_list.append("test")

train_small_dataset['destination_main_folder'] = destination_list

train_small_dataset['destination_main_folder'].value_counts()
train_small_dataset
# Out:
#       Unnamed: 0 File Name         Category  Remainder destination_main_folder
# 0              0     0.jpg    Audrey Tautou          0                   train
# 1              1     1.jpg     Adam Sandler          1                   train
# 2              2     2.jpg      Anna Paquin          2                   train
# 3              3     3.jpg      Ava Gardner          3                   train
# 4              4     4.jpg        Amy Adams          4                   train
# ...          ...       ...              ...        ...                     ...
# 6950        6950  6950.jpg     Alec Baldwin          0                   train
# 6951        6951  6951.jpg  Anthony Perkins          1                   train
# 6952        6952  6952.jpg      Aaron Judge          2                   train
# 6953        6953  6953.jpg       Bernie Mac          3                   train
# 6954        6954  6954.jpg      Ashley Judd          4                   train
#
# [6955 rows x 5 columns]

# %%
os.mkdir('/content/drive/MyDrive/' + 'train')
os.mkdir('/content/drive/MyDrive/' + 'test')
os.mkdir('/content/drive/MyDrive/' + 'validate')

# %%
train = "/content/drive/MyDrive/train/"

test = "/content/drive/MyDrive/test/"

validate = "/content/drive/MyDrive/validate/"

train_small= "/content/drive/MyDrive/train_small/train_small/"

#copying from train small image FOLDER

for column,rows in train_small_dataset.iterrows():
  if(os.path.exists(train_small+rows[1])):
    if (rows[4] == "train"):
      shutil.copy(train_small+rows[1], train+rows[1])
    elif (rows[4] == "test"):
      shutil.copy(train_small+rows[1], test+rows[1])
    elif (rows[4] == "validate"):
      shutil.copy(train_small+rows[1], validate+rows[1])
  else:
    print("Error")
# Out:
# Error

# %%
#Check the len of each folder to confirm:
import os
item_list = os.listdir('/content/drive/MyDrive/test')
test_files_list = [item for item in item_list if(os.path.isfile(os.path.join('/content/drive/MyDrive/test',item)))]
item_list = os.listdir('/content/drive/MyDrive/train')
train_files_list = [item for item in item_list if(os.path.isfile(
    os.path.join('/content/drive/MyDrive/train',item)))]
item_list = os.listdir('/content/drive/MyDrive/validate')
validate_files_list = [item for item in item_list if(os.path.isfile(
    os.path.join('/content/drive/MyDrive/validate',item)))]
print(len(test_files_list),len(train_files_list),len(validate_files_list))
# Out:
# 1390 4869 695

# %%
#Two main modes for face recognition, as:

#Face Verification. A one-to-one mapping of a given face against a known identity (e.g. is this the person?).
#Face Identification. A one-to-many mapping for a given face against a database of known faces (e.g. who is this person?).

#The VGGFace Model refers to a series of models developed for face recognition
# VGGFace and VGGFace2.

#They describe the process of training a face classifier first that uses a softmax activation function in the output layer to classify faces as people. This layer is then removed so that the output of the network is a vector feature representation of the face, called a face embedding. The model is then further trained, via fine-tuning, in order that the Euclidean distance between vectors generated for the same identity are made smaller and the vectors generated for different identities is made larger. This is achieved using a triplet loss function.

https://machinelearningmastery.com/how-to-perform-face-recognition-with-vggface2-convolutional-neural-network-in-keras/


#A face embedding is predicted by a given model as a 2,048 length vector.
#The length of the vector is then normalized, e.g. to a length of 1 or unit norm using the L2 vector norm (Euclidean distance from the origin).
#This is referred to as the ‘face descriptor‘. The distance between face descriptors (or groups of face descriptors called a ‘subject template’) is calculated using the Cosine similarity.

# %%
# !sudo pip install git+https://github.com/rcmalli/keras-vggface.git
# !pip show keras_vggface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/rcmalli/keras-vggface.git to /tmp/pip-req-build-kbrfnoxm
#   Running command git clone -q https://github.com/rcmalli/keras-vggface.git /tmp/pip-req-build-kbrfnoxm
# ...
# Name: keras-vggface
# Version: 0.6
# Summary: VGGFace implementation with Keras framework
# Home-page: https://github.com/rcmalli/keras-vggface
# Author: Refik Can MALLI
# Author-email: mallir@itu.edu.tr
# License: MIT
# Location: /usr/local/lib/python3.8/dist-packages
# Requires: pillow, pyyaml, scipy, h5py, keras, six, numpy
# Required-by:

# %%
## check version of keras_vggface
import keras_vggface
# !pip install keras_vggface
# !pip install keras_applications
print(keras_vggface.__version__)

# !pip ainstall h5py==2.10.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 0.6
# ERROR: unknown command "ainstall" - maybe you meant "install"

# %%
#In this tutorial, we will also use the Multi-Task Cascaded Convolutional Neural Network, or MTCNN, for face detection, e.g. finding and extracting faces from photos

# !sudo pip install mtcnn

import mtcnn
print(mtcnn.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 0.1.0

# %%
#GET OUR DATA TO INPUT INTO THE MODEL
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
import cv2
def extract_face(file_name, required_size = (224,224) ): #VGG model wants size 224,224
  pixels = cv2.imread(file_name)
  if(pixels.shape[2]>=3): #if 3 channels, change it to RGB from BGR
    pixels = cv2.cvtColor(pixels, cv2.COLOR_BGR2RGB) #only take first 3 channels even if >3 channels (GIF)
  elif (len(pixels.shape)==2): #if only 1 channel
    pixels = cv2.cvtColor(pixels, cv2.COLOR_GRAY2RGB)


  detector = MTCNN()
  results = detector.detect_faces(pixels)
  x1, y1, width, height = results[0]['box']   #width and height is how far and how tall is the face being detected (Ex: 5 pixels, 2 pixels)
  x2, y2 = x1 + width, y1 + height #To find bounds (ending x,y coordinates, need to add OG + width/height)
  face = pixels[y1:y2, x1:x2]
  image = Image.fromarray(face) #resize it to model size
  image = image.resize(required_size)
  face_array = asarray(image)
  return face_array
#This function just returns a np array of the extracted face pixels
#got to use imshow to then show the image from the resulting face_array pixels
#an image with scalar data. The values are mapped to colors using normalization and a colormap --

#pixels = extract_face('/content/drive/MyDrive/train/10.jpg')
#pyplot.imshow(pixels)
#pyplot.show()

# %%
#Create subfolders, extract one face per image, store that one into subfolders (name of celebrity folder)
#Train VGG based on Purdue notebook
from __future__ import absolute_import, division, print_function, unicode_literals
# !pip install keras
# !pip install numpy
import pandas as pd
import shutil
import os
from os import path


names_list=[]
for index, row in train_small_dataset.iterrows():
  names_list.append(row[2])
names_list = set(names_list)
names_list = list(names_list)
print(len(names_list))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 100

# %%
for name in names_list:
  if path.exists('/content/drive/MyDrive/train/' + name) == False:
    os.mkdir('/content/drive/MyDrive/train/' + name)

# %%
for name in names_list:
  if path.exists('/content/drive/MyDrive/test/' + name) == False:
    os.mkdir('/content/drive/MyDrive/test/' + name)

# %%
for name in names_list:
  if path.exists('/content/drive/MyDrive/validate/' + name) == False:
      os.mkdir('/content/drive/MyDrive/validate/' + name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8d465aae4f8d> in <module>
# ----> 1 for name in names_list:
#       2   if path.exists('/content/drive/MyDrive/validate/' + name) == False:
#       3       os.mkdir('/content/drive/MyDrive/validate/' + name)
#       4
#
# NameError: name 'names_list' is not defined

# %%
train_small_dataset
# Out:
#       Unnamed: 0 File Name         Category  Remainder destination_main_folder
# 0              0     0.jpg    Audrey Tautou          0                   train
# 1              1     1.jpg     Adam Sandler          1                   train
# 2              2     2.jpg      Anna Paquin          2                   train
# 3              3     3.jpg      Ava Gardner          3                   train
# 4              4     4.jpg        Amy Adams          4                   train
# ...          ...       ...              ...        ...                     ...
# 6950        6950  6950.jpg     Alec Baldwin          0                   train
# 6951        6951  6951.jpg  Anthony Perkins          1                   train
# 6952        6952  6952.jpg      Aaron Judge          2                   train
# 6953        6953  6953.jpg       Bernie Mac          3                   train
# 6954        6954  6954.jpg      Ashley Judd          4                   train
#
# [6955 rows x 5 columns]

# %%
source_folder = "/content/drive/MyDrive/train_small/train_small"

for index,rows in train_small_dataset.iterrows():
  file_name = rows[1]
  category = rows[2]
  destination = os.path.join("/content/drive/MyDrive/", rows[4], category)
  try:
    pixels = extract_face(os.path.join(source_folder,file_name))
    image = Image.fromarray(pixels)
    image.save(os.path.join(destination,file_name))
  except:
    print(file_name)
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f95c8c52b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# ...

# %%
import os
item_list = os.listdir('/content/drive/MyDrive/test')
test_files_list = [item for item in item_list if(os.path.isfile(os.path.join('/content/drive/MyDrive/test',item)))]
item_list = os.listdir('/content/drive/MyDrive/train')
train_files_list = [item for item in item_list if(os.path.isfile(
    os.path.join('/content/drive/MyDrive/train',item)))]
item_list = os.listdir('/content/drive/MyDrive/validate')
validate_files_list = [item for item in item_list if(os.path.isfile(
    os.path.join('/content/drive/MyDrive/validate',item)))]
print(len(test_files_list),len(train_files_list),len(validate_files_list))
# Out:
# 1390 4869 695

# %%
len(os.listdir('/content/drive/MyDrive/train_small/train_small'))
# Out:
# 6954

# %%
#CREATE MODEL

#The keras-vggface library provides three pre-trained VGGModels, a VGGFace1 model via model=’vgg16′ (the default), and two VGGFace2 models ‘resnet50‘ and ‘senet50‘.

# example of creating a face embedding
from keras_vggface.vggface import VGGFace

# create a vggface2 model
model = VGGFace(model="resnet50")
# summarize input and output shape
print('Inputs: %s' % model.inputs)
print('Outputs: %s' % model.outputs)


#ResNet-50 is a convolutional neural network that is 50 layers deep.
#You can load a pretrained version of the network trained on more than a million images from the ImageNet database [1].
#The pretrained network can classify images into 1000 object categories, such as keyboard, mouse, pencil, and many animals

###Model expects input color images of faces with the shape of 244×244 and the output will be a class prediction of 8,631 people
#(because the models were pretrained on a set of 8631 identities)
# Out:
# ...
# 165445632/165439116 [==============================] - 11s 0us/step
# Inputs: [<tf.Tensor 'input_1:0' shape=(None, 224, 224, 3) dtype=float32>]
# Outputs: [<tf.Tensor 'classifier/Softmax:0' shape=(None, 8631) dtype=float32>]

# %%
model.summary()
# Out:
# Model: "vggface_resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv1/7x7_s2 (Conv2D)           (None, 112, 112, 64) 9408        input_1[0][0]
# __________________________________________________________________________________________________
# conv1/7x7_s2/bn (BatchNormaliza (None, 112, 112, 64) 256         conv1/7x7_s2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           conv1/7x7_s2/bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
#Define Model
from keras.models import Model

for i in range(len(model.layers)):
  model.layers[i].trainable = False

vgg_face_descriptor = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

classifier_layers = [Dense(100,activation='softmax')] #final layer

layer_output = vgg_face_descriptor.output

for layer in classifier_layers:
      layer_output = layer(layer_output) #Add the final layer to the model

vgg_face_descriptor = Model(vgg_face_descriptor.input, layer_output)

#vgg_face_descriptor.compile(optimizer = 'adam',loss='CategoricalCrossentropy',metrics = 'accuracy')

vgg_face_descriptor.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[
        tf.keras.metrics.Accuracy()
    ]
)

# %%
from keras_vggface.utils import preprocess_input

# %%
#Training using image data generator:
#- in Purdue colab
train_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input,rotation_range=20)
val_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input)
test_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input)

# %%
train = "/content/drive/MyDrive/train/"
validate = "/content/drive/MyDrive/validate/"
test = "/content/drive/MyDrive/test/"

train_flow = train_data_generator.flow_from_directory(train, target_size = (224,224),batch_size = 64)
val_flow = val_data_generator.flow_from_directory(validate, target_size = (224,224),batch_size = 64)
test_flow = test_data_generator.flow_from_directory(test, target_size = (224,224),batch_size = 176,shuffle=False)
# Out:
# Found 1355 images belonging to 100 classes.
# Found 192 images belonging to 100 classes.
# Found 385 images belonging to 100 classes.

# %%
#Test our model:
history = vgg_face_descriptor.fit(x=train_flow,
                                  steps_per_epoch= train_flow.n//64,
                                  epochs = 50,
                                  validation_data = val_flow,
                                  validation_steps = val_flow.n//64)
# Out:
# Epoch 1/50
# 21/21 [==============================] - 299s 14s/step - loss: 5.3379 - accuracy: 0.0000e+00 - val_loss: 3.4834 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 21/21 [==============================] - 294s 14s/step - loss: 1.2898 - accuracy: 0.0000e+00 - val_loss: 2.3171 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 21/21 [==============================] - 307s 15s/step - loss: 0.4513 - accuracy: 0.0000e+00 - val_loss: 3.0662 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 21/21 [==============================] - 289s 14s/step - loss: 0.1485 - accuracy: 1.6532e-07 - val_loss: 3.1148 - val_accuracy: 1.6890e-06
# Epoch 5/50
# 21/21 [==============================] - 297s 14s/step - loss: 0.0785 - accuracy: 2.3146e-06 - val_loss: 2.5998 - val_accuracy: 4.0521e-06
# Epoch 6/50
# 21/21 [==============================] - 279s 13s/step - loss: 0.0695 - accuracy: 3.8745e-06 - val_loss: 2.6343 - val_accuracy: 4.9027e-06
# Epoch 7/50
# ...

# %%
#Testing the Model --> replaces the below code
STEP_SIZE_TEST=test_flow.n//test_flow.batch_size
test_flow.reset()
scores=vgg_face_descriptor.evaluate(test_flow,steps=STEP_SIZE_TEST,verbose=1)

# %%
#Question:
#Do we test the model by the below code?

# %%
#RUN THROUGH MODEL AND DO FACE DETECTION (GET NAME OF PERSON AND % ACCURACY) --> Testing the model using the Test Pictures --> Dont need to do
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input
from keras_vggface.utils import decode_predictions
from numpy import expand_dims

#The pixel values must be centered on each channel using the mean from the training dataset.
pixels = pixels.astype('float32')
samples = expand_dims(pixels, axis=0)
## prepare the face for the model, e.g. center pixels
samples = preprocess_input(samples, version=2)

#preprocess_input() function provided in the keras-vggface library --> pixel values are scaled using the mean values used specifically to train VGG2 (V2) models


yhat = model.predict(samples)
#returns class integers as final prediction from predict in-built keras-vggface library

results = decode_predictions(yhat) #convert predictions to name using decode_predictions() function in the keras-vggface library
#class integers mapped to celebrity names --> top 5 names with % accuracy recieved

for result in results[0]:
	print('%s: %.3f%%' % (result[0], result[1]*100))

#For each of the top 5 answers, print out the name and the accuracy as a percent value

# %%
#Verification:
#FACE VERIFICATION - GETTING DISTANCE B/W VECTOR IDENTITIES AND IF THEY ARE SMALL ENOUGH, SAY 2 images ARE A MATCH

# face verification with the VGGFace2 model
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from scipy.spatial.distance import cosine
from mtcnn.mtcnn import MTCNN
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input

# extract a single face from a given photograph
def extract_face(filename, required_size=(224, 224)):
	# load image from file
	pixels = pyplot.imread(filename)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# extract faces and calculate face embeddings for a list of photo files
def get_embeddings(filenames):
	# extract faces
	faces = [extract_face(f) for f in filenames]
	# convert into an array of samples
	samples = asarray(faces, 'float32')
	# prepare the face for the model, e.g. center pixels
	samples = preprocess_input(samples, version=2)
	# create a vggface model
	model = VGGFace(model='resnet50', include_top=False, input_shape=(224, 224, 3), pooling='avg')
	# perform prediction
	yhat = model.predict(samples)
	return yhat

# determine if a candidate face is a match for a known face
def is_match(known_embedding, candidate_embedding, thresh=0.5):
	# calculate distance between embeddings
	score = cosine(known_embedding, candidate_embedding) #distance between 2 vectors
	if score <= thresh:
		print('>face is a Match (%.3f <= %.3f)' % (score, thresh))
	else:
		print('>face is NOT a Match (%.3f > %.3f)' % (score, thresh))

# define filenames
filenames = ['/content/giselle1.jpg', '/content/giselle2.jpg',
	'/content/giselle3.jpg', '/content/amber1.jpg']
# get embeddings file filenames
embeddings = get_embeddings(filenames)
# define sharon stone
sharon_id = embeddings[0]
# verify known photos of sharon
is_match(embeddings[0], embeddings[1])
is_match(embeddings[0], embeddings[2])
# verify known photos of other people
is_match(embeddings[0], embeddings[3])
